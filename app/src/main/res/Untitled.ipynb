# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
# Базовые команды Pandas которые будем использовать:

import pandas as pd

# Загрузка
df = pd.read_csv('/Users/grig/Downloads/Student_Performance.csv')

# Осмотр
df.head()          # первые 5 строк

# print ("=====================================================================")


# df.head(3)          # первые 5 строк

# display(df.head())
# display(df.head(3))

# print(df.head(5))

# df.shape           # (строки, колонки)
# df.info()          # типы данных, пропуски
# df.describe()      # статистика по числовым колонкам
# df.columns         # список колонок
# df['gender'].value_counts()  # частота значений
# df['parent_education'].value_counts()  # частота значений
# df['internet_access'].value_counts()  # частота значений
df['english_score'].value_counts()  # частота значений
# df.shape

# df.isnull().sum()
# df[df['director'].isnull()].head()
# df['director'] = df['director'].fillna('Unknown')

# df.columns


df.head
# Out:
# <bound method NDFrame.head of        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
# ...
